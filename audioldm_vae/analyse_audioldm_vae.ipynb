# %%
from aud_utils import AudioLDM_VAE
from IPython.display import Audio

# %%
vae_obj = AudioLDM_VAE()
# Out:
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 154707.93it/s]
# /home/sxk230060/ltx_lora_training_i2v_t2v/more_scripts/audioldm_vae/audioldm/audio/stft.py:42: FutureWarning: Pass size=1024 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   fft_window = pad_center(fft_window, filter_length)
# /home/sxk230060/ltx_lora_training_i2v_t2v/more_scripts/audioldm_vae/audioldm/audio/stft.py:151: FutureWarning: Pass sr=16000, n_fft=1024, n_mels=64, fmin=0, fmax=8000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_basis = librosa_mel_fn(

# %%
audio_path = '/mnt/ssd0/saksham/i2av/AVSync15/audios_together/I4JKaLOIEGs_000030_000040_3.0_6.0.wav'
latent = vae_obj.audio_to_latent([audio_path], target_length=512)

# %%
latent.shape
# Out:
# torch.Size([1, 8, 128, 16])

# %%
rec_audio = vae_obj.latent_to_audio(latent)

# %%
Audio(audio_path, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(rec_audio, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
